# %% [markdown]
# <a href="https://colab.research.google.com/github/dorianxiao/DLexp/blob/master/Exp7%3A%E8%8B%B1%E6%96%87%E6%95%B0%E5%AD%97%E8%AF%AD%E9%9F%B3%E8%AF%86%E5%88%AB/asrcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 挂载到Google Drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os

# 更改工作目录
os.chdir(r'/content/gdrive/My Drive/mylab/Exp7')
print(os.getcwd())
# Out:
# /content/gdrive/My Drive/mylab/Exp7

# %%
# 导入相关库

from __future__ import division, print_function, absolute_import
import tensorflow as tf
import os
import numpy as np
import librosa
from random import shuffle

# %%
# 参数设置

class CNNConfig(object):
    """CNN配置参数"""
    num_filters = 64  # 卷积核数目
    filter_sizes = [2,3,4,5]  # 卷积核尺寸
    hidden_dim = 32  # 全连接层神经元
    dropout_keep_prob = 1  # dropout保留比例
    learning_rate = 1e-3  # 学习率
    num_epochs = 1000  # 总迭代轮次
    batch_size = 128
    print_per_batch = 20
    save_tb_per_batch = 10

# %%
# 构建模型

class ASRCNN(object):
    def __init__(self, config, width, height, num_classes):  # 20,100
        self.config = config
        self.input_x = tf.placeholder(tf.float32, [None, width, height], name='input_x')
        self.input_y = tf.placeholder(tf.float32, [None, num_classes], name='input_y')
        self.keep_prob = tf.placeholder(tf.float32, name='keep_prob')

        # input_x = tf.reshape(self.input_x, [-1, height, width])
        input_x = tf.transpose(self.input_x, [0, 2, 1])
        pooled_outputs = []
        for i, filter_size in enumerate(self.config.filter_sizes):
            with tf.name_scope("conv-maxpool-%s" % filter_size):
                print("conv-maxpool-%s" % filter_size)
                conv = tf.layers.conv1d(input_x, self.config.num_filters, filter_size, activation=tf.nn.relu)
                pooled = tf.reduce_max(conv, reduction_indices=[1])
                pooled_outputs.append(pooled)
        num_filters_total = self.config.num_filters * len(self.config.filter_sizes)  # 64*4
        pooled_reshape = tf.reshape(tf.concat(pooled_outputs, 1), [-1, num_filters_total])
        #pooled_flat = tf.nn.dropout(pooled_reshape, self.keep_prob)

        fc = tf.layers.dense(pooled_reshape, self.config.hidden_dim, activation=tf.nn.relu, name='fc1')
        fc = tf.contrib.layers.dropout(fc, self.keep_prob)
        #fc = tf.nn.relu(fc)
        # 分类器
        self.logits = tf.layers.dense(fc, num_classes, name='fc2')
        self.y_pred_cls = tf.argmax(tf.nn.softmax(self.logits), 1, name="pred")  # 预测类别
        # 损失函数，交叉熵
        cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=self.logits, labels=self.input_y)
        self.loss = tf.reduce_mean(cross_entropy)
        # 优化器
        self.optim = tf.train.AdamOptimizer(learning_rate=self.config.learning_rate).minimize(self.loss)
        # 准确率
        correct_pred = tf.equal(tf.argmax(self.input_y, 1), self.y_pred_cls)
        self.acc = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
# 对音频文件特征MFCC进行提取
def read_files(files):
    labels = []
    features = []
    for ans, files in files.items():
        for file in files:
            wave, sr = librosa.load(file, mono=True)
            label = dense_to_one_hot(ans, 10)
            labels.append(label)
            mfcc = librosa.feature.mfcc(wave, sr)
            mfcc = np.pad(mfcc, ((0, 0), (0, 100 - len(mfcc[0]))), mode='constant', constant_values=0)
            features.append(np.array(mfcc))
    return np.array(features), np.array(labels)

  # 对特征向量进行归一化处理
def dense_to_one_hot(labels_dense, num_classes=10):
    """Convert class labels from scalars to one-hot vectors."""
    return np.eye(num_classes)[labels_dense]

# %%
def load_files(path=r'/content/gdrive/My Drive/mylab/Exp7/numbersRec/recordings/'):
    files = os.listdir(path)
    cls_files = {}
    for wav in files:
        if not wav.endswith(".wav"): continue
        ans = int(wav[0])
        cls_files.setdefault(ans, [])
        cls_files[ans].append(path + wav)
    train_files = {}
    valid_files = {}
    test_files = {}
    for ans, file_list in cls_files.items():
        shuffle(file_list)
        all_len = len(file_list)
        train_len = int(all_len * 0.7)
        valid_len = int(all_len * 0.2)
        test_len = all_len - train_len - valid_len
        train_files[ans] = file_list[0:train_len]
        valid_files[ans] = file_list[train_len:train_len + valid_len]
        test_files[ans] = file_list[all_len - test_len:all_len]
    return train_files, valid_files, test_files


def batch_iter(X, Y, batch_size=128):
    data_len = len(X)
    num_batch = int((data_len - 1) / batch_size) + 1

    indices = np.random.permutation(np.arange(data_len))
    x_shuffle = X[indices]
    y_shuffle = Y[indices]

    for i in range(num_batch):
        start_id = i * batch_size
        end_id = min((i + 1) * batch_size, data_len)
        yield x_shuffle[start_id:end_id], y_shuffle[start_id:end_id]


def feed_data(cnn, x_batch, y_batch, keep_prob):
    feed_dict = {
        cnn.input_x: x_batch,
        cnn.input_y: y_batch,
        cnn.keep_prob: keep_prob
    }
    return feed_dict


def mean_normalize(features):
    std_value = features.std()
    mean_value = features.mean()
    return (features - mean_value) / std_value

# %%
# 模型训练
def train(argv=None):
    '''batch = mfcc_batch_generator()
    X, Y = next(batch)
    trainX, trainY = X, Y
    testX, testY = X, Y  # overfit for now'''
    train_files, valid_files, test_files = load_files()
    train_features, train_labels = read_files(train_files)
    train_features = mean_normalize(train_features)
    print('读取训练文件')
    valid_features, valid_labels = read_files(valid_files)
    valid_features = mean_normalize(valid_features)
    print('读取验证文件')
    test_features, test_labels = read_files(test_files)
    test_features = mean_normalize(test_features)
    print('读取测试文件')

    width = 20  # mfcc features
    height = 100  # (max) length of utterance
    classes = 10  # digits

    config = CNNConfig
    cnn = ASRCNN(config, width, height, classes)
    session = tf.Session()
    session.run(tf.global_variables_initializer())
    saver = tf.train.Saver(tf.global_variables())
    checkpoint_path = os.path.join('cnn_model', 'model.ckpt')
    tensorboard_train_dir = 'tensorboard/train'
    tensorboard_valid_dir = 'tensorboard/valid'

    if not os.path.exists(tensorboard_train_dir):
        os.makedirs(tensorboard_train_dir)
    if not os.path.exists(tensorboard_valid_dir):
        os.makedirs(tensorboard_valid_dir)
    tf.summary.scalar("loss", cnn.loss)
    tf.summary.scalar("accuracy", cnn.acc)
    merged_summary = tf.summary.merge_all()
    train_writer = tf.summary.FileWriter(tensorboard_train_dir)
    valid_writer = tf.summary.FileWriter(tensorboard_valid_dir)

    total_batch = 0
    for epoch in range(config.num_epochs):
        print('Epoch:', epoch + 1)
        batch_train = batch_iter(train_features, train_labels)
        for x_batch, y_batch in batch_train:
            total_batch += 1
            feed_dict = feed_data(cnn, x_batch, y_batch, config.dropout_keep_prob)
            session.run(cnn.optim, feed_dict=feed_dict)
            if total_batch % config.print_per_batch == 0:
                train_loss, train_accuracy = session.run([cnn.loss, cnn.acc], feed_dict=feed_dict)
                valid_loss, valid_accuracy = session.run([cnn.loss, cnn.acc], feed_dict={cnn.input_x: valid_features,
                                                                                         cnn.input_y: valid_labels,
                                                                                         cnn.keep_prob: config.dropout_keep_prob})
                print('Steps:' + str(total_batch))
                print(
                    'train_loss:' + str(train_loss) + ' train accuracy:' + str(train_accuracy) + '\tvalid_loss:' + str(
                        valid_loss) + ' valid accuracy:' + str(valid_accuracy))
            if total_batch % config.save_tb_per_batch == 0:
                train_s = session.run(merged_summary, feed_dict=feed_dict)
                train_writer.add_summary(train_s, total_batch)
                valid_s = session.run(merged_summary, feed_dict={cnn.input_x: valid_features, cnn.input_y: valid_labels,
                                                                 cnn.keep_prob: config.dropout_keep_prob})
                valid_writer.add_summary(valid_s, total_batch)

        saver.save(session, checkpoint_path, global_step=epoch)
    test_loss, test_accuracy = session.run([cnn.loss, cnn.acc],
                                           feed_dict={cnn.input_x: test_features, cnn.input_y: test_labels,
                                                      cnn.keep_prob: config.dropout_keep_prob})
    print('test_loss:' + str(test_loss) + ' test accuracy:' + str(test_accuracy))

# %%
## 模型训练
train()
# Out:
# 读取训练文件
# 读取验证文件
# 读取测试文件
# conv-maxpool-2
# WARNING:tensorflow:From <ipython-input-7-06216ccc4679>:15: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv1d instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# conv-maxpool-3
# conv-maxpool-4
# conv-maxpool-5
# WARNING:tensorflow:From <ipython-input-7-06216ccc4679>:22: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From <ipython-input-7-06216ccc4679>:29: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch: 1
# Steps:20
# train_loss:2.2734833 train accuracy:0.1796875	valid_loss:2.3104527 valid accuracy:0.1465629
# Epoch: 2
# Steps:40
# train_loss:2.1314383 train accuracy:0.28125	valid_loss:2.1812034 valid accuracy:0.2619974
# Epoch: 3
# Steps:60
# train_loss:2.0804548 train accuracy:0.3125	valid_loss:2.0780075 valid accuracy:0.3450065
# Epoch: 4
# Steps:80
# train_loss:1.9229325 train accuracy:0.375	valid_loss:1.9811429 valid accuracy:0.3605707
# Epoch: 5
# Steps:100
# train_loss:1.9136987 train accuracy:0.3671875	valid_loss:1.8925583 valid accuracy:0.4319066
# Epoch: 6
# Steps:120
# train_loss:1.6948633 train accuracy:0.4765625	valid_loss:1.7939196 valid accuracy:0.4474708
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Epoch: 7
# Steps:140
# train_loss:1.655 train accuracy:0.4765625	valid_loss:1.7136977 valid accuracy:0.4215305
# Epoch: 8
# Steps:160
# train_loss:1.5637081 train accuracy:0.53125	valid_loss:1.6137838 valid accuracy:0.5071336
# Epoch: 9
# Steps:180
# train_loss:1.3872236 train accuracy:0.5625	valid_loss:1.536411 valid accuracy:0.5616083
# Epoch: 10
# Steps:200
# train_loss:1.334612 train accuracy:0.671875	valid_loss:1.4463476 valid accuracy:0.538262
# Steps:220
# train_loss:1.2807024 train accuracy:0.6060606	valid_loss:1.3826606 valid accuracy:0.55901426
# Epoch: 11
# Steps:240
# train_loss:1.2016344 train accuracy:0.6953125	valid_loss:1.2980982 valid accuracy:0.58365756
# Epoch: 12
# Steps:260
# train_loss:1.1165037 train accuracy:0.6875	valid_loss:1.2314695 valid accuracy:0.6264591
# Steps:6060
# train_loss:0.002971509 train accuracy:1.0	valid_loss:0.08577589 valid accuracy:0.97405964
# Epoch: 277
# Steps:6080
# train_loss:0.0016817888 train accuracy:1.0	valid_loss:0.08288289 valid accuracy:0.9753567
# Epoch: 278
# Steps:6100
# train_loss:0.0027008357 train accuracy:1.0	valid_loss:0.08220296 valid accuracy:0.9766537
# Epoch: 279
# Steps:6120
# train_loss:0.0023498063 train accuracy:1.0	valid_loss:0.08395533 valid accuracy:0.97146565
# Epoch: 280
# Steps:6140
# train_loss:0.002903313 train accuracy:1.0	valid_loss:0.08867004 valid accuracy:0.96627754
# Steps:6160
# train_loss:0.0027411345 train accuracy:1.0	valid_loss:0.08906966 valid accuracy:0.9688716
# Epoch: 281
# Steps:6180
# train_loss:0.0029122243 train accuracy:1.0	valid_loss:0.08788259 valid accuracy:0.9701686
# Epoch: 282
# Steps:6200
# train_loss:0.0022465568 train accuracy:1.0	valid_loss:0.08492119 valid accuracy:0.9701686
# Epoch: 283
# Steps:6220
# train_loss:0.0014352013 train accuracy:1.0	valid_loss:0.08458261 valid accuracy:0.9701686
# Epoch: 284
# Steps:6240
# train_loss:0.0017552456 train accuracy:1.0	valid_loss:0.086864814 valid accuracy:0.9701686
# Epoch: 285
# Steps:6260
# train_loss:0.0021970943 train accuracy:1.0	valid_loss:0.08138405 valid accuracy:0.97276264
# Epoch: 286
# Steps:6280
# train_loss:0.002226554 train accuracy:1.0	valid_loss:0.083563454 valid accuracy:0.9753567
# Epoch: 287
# Steps:6300
# train_loss:0.0014817924 train accuracy:1.0	valid_loss:0.08553838 valid accuracy:0.97405964
# Epoch: 288
# Steps:6320
# train_loss:0.0015116286 train accuracy:1.0	valid_loss:0.08425886 valid accuracy:0.9688716
# Epoch: 289
# Steps:6340
# train_loss:0.0022978792 train accuracy:1.0	valid_loss:0.08301949 valid accuracy:0.97146565
# Epoch: 290
# Steps:6360
# train_loss:0.0016622571 train accuracy:1.0	valid_loss:0.089295 valid accuracy:0.96498054
# Steps:6380
# train_loss:0.0018964619 train accuracy:1.0	valid_loss:0.08133228 valid accuracy:0.97276264
# Epoch: 291
# Steps:6400
# train_loss:0.0020612378 train accuracy:1.0	valid_loss:0.0803431 valid accuracy:0.97276264
# Epoch: 292
# Steps:6420
# train_loss:0.0021393267 train accuracy:1.0	valid_loss:0.08319178 valid accuracy:0.97146565
# Epoch: 293
# Steps:6440
# train_loss:0.0014136366 train accuracy:1.0	valid_loss:0.087600954 valid accuracy:0.9688716
# Epoch: 294
# Steps:6460
# train_loss:0.0017985592 train accuracy:1.0	valid_loss:0.07813017 valid accuracy:0.97276264
# Epoch: 295
# Steps:6480
# train_loss:0.0017752853 train accuracy:1.0	valid_loss:0.07914693 valid accuracy:0.97405964
# Epoch: 296
# Steps:6500
# train_loss:0.002031824 train accuracy:1.0	valid_loss:0.088051766 valid accuracy:0.97146565
# Epoch: 297
# Steps:6520
# train_loss:0.0014930428 train accuracy:1.0	valid_loss:0.08139443 valid accuracy:0.9753567
# Epoch: 298
# Steps:6540
# train_loss:0.002293924 train accuracy:1.0	valid_loss:0.08919407 valid accuracy:0.9701686
# Epoch: 299
# Steps:6560
# train_loss:0.0016777072 train accuracy:1.0	valid_loss:0.080574565 valid accuracy:0.97276264
# Epoch: 300
# Steps:6580
# train_loss:0.001642721 train accuracy:1.0	valid_loss:0.080738805 valid accuracy:0.9688716
# Steps:6600
# train_loss:0.0014843848 train accuracy:1.0	valid_loss:0.083948225 valid accuracy:0.97276264
# Epoch: 301
# Steps:6620
# train_loss:0.0011968269 train accuracy:1.0	valid_loss:0.09102512 valid accuracy:0.9701686
# Epoch: 302
# Steps:6640
# train_loss:0.0014510547 train accuracy:1.0	valid_loss:0.07934752 valid accuracy:0.97405964
# Epoch: 303
# Steps:6660
# train_loss:0.0016574822 train accuracy:1.0	valid_loss:0.08054526 valid accuracy:0.9753567
# Epoch: 304
# Steps:6680
# train_loss:0.0018395677 train accuracy:1.0	valid_loss:0.08267492 valid accuracy:0.9701686
# Epoch: 305
# Steps:6700
# train_loss:0.0011056119 train accuracy:1.0	valid_loss:0.08160101 valid accuracy:0.97405964
# Epoch: 306
# Steps:6720
# train_loss:0.001352996 train accuracy:1.0	valid_loss:0.080109164 valid accuracy:0.97405964
# Epoch: 307
# Steps:6740
# train_loss:0.001713332 train accuracy:1.0	valid_loss:0.08415254 valid accuracy:0.97146565
# Epoch: 308
# Steps:6760
# train_loss:0.0014780792 train accuracy:1.0	valid_loss:0.08048607 valid accuracy:0.97276264
# Epoch: 309
# Steps:6780
# train_loss:0.001255815 train accuracy:1.0	valid_loss:0.087136306 valid accuracy:0.9688716
# Epoch: 310
# Steps:6800
# train_loss:0.0016332661 train accuracy:1.0	valid_loss:0.076777846 valid accuracy:0.9779507
# Steps:6820
# train_loss:0.0014801782 train accuracy:1.0	valid_loss:0.080604106 valid accuracy:0.9753567
# Epoch: 311
# Steps:6840
# train_loss:0.0012444718 train accuracy:1.0	valid_loss:0.08206885 valid accuracy:0.97405964
# Epoch: 312
# Steps:6860
# train_loss:0.0009933558 train accuracy:1.0	valid_loss:0.08255339 valid accuracy:0.9688716
# Epoch: 313
# Steps:6880
# train_loss:0.0011721898 train accuracy:1.0	valid_loss:0.08111871 valid accuracy:0.9753567
# Epoch: 314
# Steps:6900
# train_loss:0.0013743602 train accuracy:1.0	valid_loss:0.079040654 valid accuracy:0.97146565
# Epoch: 315
# Steps:6920
# train_loss:0.0010547701 train accuracy:1.0	valid_loss:0.080948964 valid accuracy:0.97276264
# Epoch: 316
# Steps:6940
# train_loss:0.0013076866 train accuracy:1.0	valid_loss:0.0797104 valid accuracy:0.97146565
# Epoch: 317
# Steps:6960
# train_loss:0.0009811923 train accuracy:1.0	valid_loss:0.079218395 valid accuracy:0.97276264
# Epoch: 318
# Steps:6980
# train_loss:0.0011616228 train accuracy:1.0	valid_loss:0.08219439 valid accuracy:0.9688716
# Epoch: 319
# Steps:7000
# train_loss:0.0011164255 train accuracy:1.0	valid_loss:0.07887792 valid accuracy:0.97146565
# Epoch: 320
# train_loss:2.0489088e-07 train accuracy:1.0	valid_loss:0.089845255 valid accuracy:0.9831388
# Epoch: 994
# Steps:21860
# train_loss:2.2537992e-07 train accuracy:1.0	valid_loss:0.089605436 valid accuracy:0.9844358
# Epoch: 995
# Steps:21880
# train_loss:2.1699802e-07 train accuracy:1.0	valid_loss:0.0875376 valid accuracy:0.9857328
# Epoch: 996
# Steps:21900
# train_loss:2.067535e-07 train accuracy:1.0	valid_loss:0.089437366 valid accuracy:0.9831388
# Epoch: 997
# Steps:21920
# train_loss:2.3189915e-07 train accuracy:1.0	valid_loss:0.08721297 valid accuracy:0.9857328
# Epoch: 998
# Steps:21940
# train_loss:1.862644e-07 train accuracy:1.0	valid_loss:0.08901398 valid accuracy:0.9844358
# Epoch: 999
# Steps:21960
# train_loss:2.0954744e-07 train accuracy:1.0	valid_loss:0.08107059 valid accuracy:0.98702985
# Epoch: 1000
# Steps:21980
# train_loss:1.769512e-07 train accuracy:1.0	valid_loss:0.092282414 valid accuracy:0.9831388
# Steps:22000
# train_loss:1.9868207e-07 train accuracy:1.0	valid_loss:0.08532977 valid accuracy:0.9844358
# test_loss:0.118155375 test accuracy:0.97744364

# %%
# 准备测试数据

def read_test_wave(path):
    files = os.listdir(path)
    feature = []
    features = []
    label = []
    for wav in files:
        # print(wav)
        if not wav.endswith(".wav"): continue
        ans = int(wav[0])        
        wave, sr = librosa.load(path+wav, mono=True)
        label.append(ans)
        # print("真实lable: %d" % ans)
        mfcc = librosa.feature.mfcc(wave, sr)
        mfcc = np.pad(mfcc, ((0, 0), (0, 100 - len(mfcc[0]))), mode='constant', constant_values=0)
        feature.append(np.array(mfcc))   
    features = mean_normalize(np.array(feature))
    return features,label

# %%
# 模型加载

def test(path):
    features, label = read_test_wave(path)
    print('loading ASRCNN model...')
    with tf.Session() as sess:
        saver = tf.train.import_meta_graph('cnn_model/model.ckpt-999.meta')
        saver.restore(sess, tf.train.latest_checkpoint('cnn_model'))  
        graph = tf.get_default_graph()
        input_x = graph.get_tensor_by_name("input_x:0")
        pred = graph.get_tensor_by_name("pred:0")
        keep_prob = graph.get_tensor_by_name("keep_prob:0")
        for i in range(0, len(label)):
            feed_dict = {input_x: features[i].reshape(1,20,100), keep_prob: 1.0}
            test_output = sess.run(pred, feed_dict=feed_dict)
            
            print("="*15)
            print("真实lable: %d" % label[i])
            print("识别结果为:"+str(test_output[0]))
        print("祝贺你大兄弟!")

# %%
path = r'/content/gdrive/My Drive/mylab/Exp7/numbersRec/test/'
test(path)
# Out:
# loading ASRCNN model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from cnn_model/model.ckpt-999
# ===============
# 真实lable: 6
# 识别结果为:6
# ===============
# 真实lable: 1
# 识别结果为:1
# ===============
# 真实lable: 5
# 识别结果为:5
# ===============
# 真实lable: 4
# 识别结果为:4
# ===============
# 真实lable: 3
# 识别结果为:3
# ===============
# 真实lable: 0
# 识别结果为:0
# ===============
# 真实lable: 7
# 识别结果为:7
# ===============
# 真实lable: 8
# 识别结果为:8
# ===============
# 真实lable: 9
# 识别结果为:9
# 祝贺你大兄弟!
