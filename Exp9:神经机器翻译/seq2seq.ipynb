# %% [markdown]
# <a href="https://colab.research.google.com/github/dorianxiao/DLexp/blob/master/Exp9%3A%E7%A5%9E%E7%BB%8F%E6%9C%BA%E5%99%A8%E7%BF%BB%E8%AF%91/seq2seq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 挂载到Google Drive

from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# 更改当前工作目录
import os

os.chdir(r'/content/gdrive/My Drive/mylab/Exp8')
print(os.getcwd())
# Out:
# /content/gdrive/My Drive/mylab/Exp8

# %%
#!git clone https://github.com/tensorflow/nmt/

# %%
# !mkdir model

# %%
# !ls -l
# Out:
# total 14
# drwx------ 2 root root 4096 May 27 11:39 data
# -rw------- 1 root root 1350 May 27 18:46 infer_file.zh
# drwx------ 2 root root 4096 May 27 18:49 model
# drwx------ 2 root root 4096 May 27 13:37 nmt

# %%
# !python -m nmt.nmt.nmt \
    --attention=scaled_luong \
    --src=zh --tgt=en \
    --vocab_prefix=./data/vocab  \
    --train_prefix=./data/train \
    --dev_prefix=./data/dev  \
    --test_prefix=./data/test \
    --out_dir=./model \
    --num_train_steps=12000 \
    --steps_per_stats=100 \
    --num_layers=2 \
    --num_units=128 \
    --dropout=0.2 \
    --metrics=bleu
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# # Job id 0
# 2019-05-27 18:49:33.315177: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-27 18:49:33.315492: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2fde520 executing computations on platform Host. Devices:
# 2019-05-27 18:49:33.315526: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-27 18:49:33.535053: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python -m nmt.nmt.nmt \
    --out_dir=./model \
    --inference_input_file=./infer_file.zh \
    --inference_output_file=./output_infer
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# # Job id 0
# 2019-05-27 19:39:10.619897: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-27 19:39:10.620123: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2a40520 executing computations on platform Host. Devices:
# 2019-05-27 19:39:10.620156: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-27 19:39:10.797441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !cat infer_file.zh
# Out:
# 市场 竞争 不仅 是 数量 的 较量 , 更 重要 的 是 技术 , 质量 和 效率 的 角逐 .
# 可以 预见 , 在 新世纪 中 , 中国 经济 将 在 新 的 起点 以 更大 的 规模 向前 发展 .
# 抗美援朝 战争 中 , 志愿军 与 全国 人民 息息相通 , 血肉相连 .
# 另外 , 我国 地区 之间 经济 发展 也 不平衡 , 产业 结构 还 不合理 , 科学技术 还 比较 落后 , 企业 的 整体 素质 和 竞争 能力 还 不 强 , 等等 .
# 特别 强调 , 对 领导干部 要 加强 主动 监督 , 把 监督 关口 往前 移 , 加强 事前 防范 .
# 从 古今中外 的 历史 经验 和 现实 状况 看 , 能否 处理好 民族 问题 , 对 国家 统一 , 经济 发展 , 政治 稳定 和 社会 进步 , 都 至关重要 .
# 一切 都要 从 我国 国情 出发 , 从 建设 有 中国 特色 社会主义 的 实际 出发 , 这 才是 历史唯物主义 的 真谛 , 是 中国 共产党 人 应有 的 马克思主义 学风 .
# 李鹏 委员长 分别 向 六 国 相应 领导人 转达 了 江泽民 主席 , 朱 ( 金字 旁 容 ) 基 总理 的 问候 和 祝愿 .
# 如今 , 在 美国 的 驴 像 相争 的 " 跷跷板 游戏 " 中 , 美国 标榜 为 " 民主 " 政治 像 征 的 大选 , 在 金钱 面前 已 黯然失色 .
# 当今 时代 和平 与 发展 是 主流 .

# %%
# !cat output_infer
# Out:
# market competition not only is a trial of a certain extent and more importantly is to use the use of technological and efficiency .
# it can predict that the chinese economy will develop the development of the new starting point in the new century .
# the chinese people 's volunteers are located in the war of aggression and aid korea .
# besides , the economic development of the china region also has restricted the irrational quality of the economy and the overall quality of the industry also lags far behind the overall quality and competition capability of the enterprises .
# particularly emphasis stressed that the leading cadres should strengthen supervision over the initiative and make supervision over the past to step up the work of preventing the work of the building of the leading cadres .
# ...
